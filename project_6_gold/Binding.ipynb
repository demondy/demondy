# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno

# %%
gold_am = pd.read_csv('./data/GOLDAM.csv', index_col=[0])
gold_pm = pd.read_csv('./data/GOLDPM.csv', index_col=[0])
gvzcls = pd.read_csv('./data/GVZCLS.csv', index_col=[0])
vxdxcls = pd.read_csv('./data/VXGDXCLS.csv', index_col=[0])
boa_ice = pd.read_csv('./data/BAML.csv', index_col=[0])
sp500 = pd.read_csv('./data/SP500.csv', index_col=[0])

# %%
gold_am
# Out:
#            GOLDAMGBD228NLBM
# DATE
# 1968-04-01           38.000
# 1968-04-02           37.600
# 1968-04-03           37.700
# 1968-04-04           36.700
# 1968-04-05           37.200
# ...                     ...
# 2021-09-02          1815.15
# 2021-09-03          1812.05
# 2021-09-06          1823.85
# 2021-09-07          1810.75
# 2021-09-08          1797.95
#
# [13943 rows x 1 columns]

# %%
df = gold_am.join(gold_pm, how='outer').join(gvzcls, how='outer').join(vxdxcls, how='outer').join(boa_ice, how='outer').join(sp500, how='outer')

# %%
df.head()
# Out:
#            GOLDAMGBD228NLBM GOLDPMGBD228NLBM GVZCLS VXGDXCLS BAMLH0A0HYM2  \
# DATE
# 1968-04-01           38.000              NaN    NaN      NaN          NaN
# 1968-04-02           37.600              NaN    NaN      NaN          NaN
# 1968-04-03           37.700              NaN    NaN      NaN          NaN
# 1968-04-04           36.700              NaN    NaN      NaN          NaN
# 1968-04-05           37.200              NaN    NaN      NaN          NaN
#
#            SP500
# DATE
# 1968-04-01   NaN
# 1968-04-02   NaN
# 1968-04-03   NaN
# 1968-04-04   NaN
# 1968-04-05   NaN

# %%
df.dropna(subset=['SP500'], inplace=True)

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
msno.bar(df)
# Out:
# <AxesSubplot:>

# %%
df.to_csv('./data/df.csv')

# %% [markdown]
# My goal is to tie some of these metrics to predict gold price. While I am certainly on track for that, I am unhappy with the scope of work. It feels basic. I am considering ways to expand and make the project more worthwhile.
